# %% [markdown]
# # RESULTADOS

# %% [markdown]
# ## Anotación

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy as sa

#Automcompletar rápido
# %config IPCompleter.greedy=True

pd.options.display.max_columns = None

con = sa.create_engine('sqlite:///../../Datos_3/airbnb.db')

df = pd.read_sql('df_preparado', con = con)

#Minicubo:

metricas = ['precio_total','precio_compra']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_precio = df[dimensiones + metricas]

minicubo_precio = minicubo_precio.melt(id_vars=['precio_total','precio_compra'])

minicubo_precio = minicubo_precio.groupby(['variable','value'])[['precio_total','precio_compra']].agg('median')

# %%
con = sa.create_engine('sqlite:///../../Datos_3/airbnb.db')

df = pd.read_sql('df_preparado', con = con)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17367 entries, 0 to 17366
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   level_0                         17367 non-null  int64
#  1   index                           17367 non-null  int64
#  2   id                              17367 non-null  int64
#  3   name                            17364 non-null  object
#  4   host_id                         17367 non-null  int64
#  5   neighbourhood_group             17367 non-null  object
#  6   neighbourhood                   17367 non-null  object
#  7   latitude                        17367 non-null  float64
#  8   longitude                       17367 non-null  float64
#  9   room_type                       17367 non-null  object
#  10  price                           17367 non-null  int64
#  11  minimum_nights                  17367 non-null  int64
#  12  calculated_host_listings_count  17367 non-null  int64
#  13  availability_365                17367 non-null  int64
#  14  description                     16435 non-null  object
#  15  host_is_superhost               17350 non-null  object
#  16  accommodates                    17367 non-null  int64
#  17  bedrooms                        17367 non-null  float64
#  18  beds                            17367 non-null  float64
#  19  number_of_reviews               17367 non-null  int64
#  20  review_scores_rating            12868 non-null  float64
#  21  review_scores_communication     12654 non-null  float64
#  22  review_scores_location          12651 non-null  float64
#  23  precio_m2                       17367 non-null  int64
#  24  distrito                        17367 non-null  object
#  25  precio_total                    17367 non-null  float64
#  26  ocupacion                       17367 non-null  int64
#  27  bedrooms_disc                   17367 non-null  object
#  28  accommodates_disc               17367 non-null  object
#  29  beds_disc                       17367 non-null  object
#  30  number_of_reviews_disc          17367 non-null  object
#  31  m2                              17367 non-null  int64
#  32  precio_compra                   17367 non-null  float64
#  33  pdi_sol                         17367 non-null  float64
# dtypes: float64(10), int64(13), object(11)
# memory usage: 4.5+ MB

# %% [markdown]
# ## CONTEXTO DEL ANALISIS

# %% [markdown]
# La empresa ha seleccionado la ciudad de Madrid como candidata para buscar inmuebles en los que invertir con el objetivo de obtener rentabilidad mediante alquiler turístico.
#
# Para ello, antes de poner al equipo de valoraciones a buscar oportunidades, la dirección ha encargado al equipo de Data Science un análisis que permita identificar estrategias o líneas de trabajo que ayuden al equipo de valoraciones.

# %% [markdown]
# ## OBJETIVOS

# %% [markdown]
# Analizar las fuentes de datos públicas disponibles para:
#
# * Encontrar insights que ayuden a entender las características del mercado en esta ciudad
# * Guiar el trabajo de búsqueda del equipo de valoraciones
#
# Especialmente en cuanto a los principales ejes: precio del alquiler, niveles de ocupación y precio de compra

# %% [markdown]
# ## CONCLUSIONES

# %% [markdown]
# * Se han localizado 10 barrios en los que centrar la búsqueda
# * Se recomienda buscar inmuebles con un habitación que permitan alojar 4 huéspedes
# * Se recomienda buscar inmuebles que, estando en uno de los barrios identificados, no estén necesariamente cerca de puntos de interés
# * Se recomienda evaluar el desarrollo de un nuevo producto basado en el alquier para momentos concretos de alto interés deportivo, especialmente en el barrio de San Blas

# %% [markdown]
# ## DETALLE DE LOS PRINCIPALES RESULTADOS

# %% [markdown]
# ### Existen 10 barrios con alto potencial de inversión

# %% [markdown]
# * Se han localizado 10 barrios que apriori pueden maximizar la relación coste-ingresos
# * Además podemos segmentarlos por el tipo calidad del inmueble en el que nos interese invertir en 4 grandes grupos
# * Estos son los 10 barrios donde comenzar a buscar oportunidades concretas:
#     * Inversión baja: Simancas, Ambroz, Marroquina, San Juan Bautista
#     * Inversión media: El Plantio, Valdemarín, Valdefuentes
#     * Inversión media-alta: Jerónimos, Fuentela reina
#     * Inversión alta: Recoletos

# %%
no_incluir = ['Rosas','Arcos','Canillejas','Hellín']

temp = df.groupby('neighbourhood')[['precio_total','precio_compra']].median()

temp = temp[~temp.index.isin(no_incluir)]

plt.figure(figsize = (16,12))
sns.set_style('darkgrid')
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# ### Buscar inmuebles de una habitación que permitan 4 huéspedes

# %% [markdown]
# * El número de huéspedes que maximiza el precio de compra pagado es de 4

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['accommodates_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['accommodates_disc'].precio_compra,color = 'green');

# %% [markdown]
# ### Buscar inmuebles que estando en uno de los barrios identificados no estén necesariamente cerca de puntos de interés

# %% [markdown]
# * Previsiblemente tendrán menor precio de compra
# * Parece que la cercanía a puntos de interés no tiene un impacto importante sobre el precio del alquiler

# %%
seleccion = df.groupby('distrito').pdi_sol.median().sort_values()[0:7].index.to_list()

plt.figure(figsize = (16,12))
sns.scatterplot(data = df.loc[df.distrito.isin(seleccion)], x = 'pdi_sol', y = 'precio_total');

# %% [markdown]
# ### Evaluar el desarrollo de un nuevo producto basado en el alquier para momentos concretos de alto interés deportivo

# %% [markdown]
# * Buscar oportunidades en el barrio de San Blas
# * Todavía existen muchos alquileres que no están explotando este potencial

# %%
temp = df.groupby('distrito')[['precio_total','precio_compra']].median()

plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %%
import folium

datos = df[df.distrito == 'San Blas - Canillejas'].copy()

datos['precio_total_disc'] = pd.qcut(datos['precio_total'], q = [0, .25, .5, .75, 1.], 
                              labels=['yellow', 'orange', 'blue', 'red'])

mapa = folium.Map(location=[datos.iloc[0,7], datos.iloc[0,8]],zoom_start=14)

for piso in range(0,len(datos)):
   folium.CircleMarker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
      fill=True,
      color = datos.iloc[piso]['precio_total_disc'],
      fill_opacity=1,
      radius = 5
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48e9e52e53e508fbdb9ac5cb4feedce0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48e9e52e53e508fbdb9ac5cb4feedce0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48e9e52e53e508fbdb9ac5cb4feedce0 = L.map(
#                 &quot;map_48e9e52e53e508fbdb9ac5cb4feedce0&quot;,
#                 {
#                     center: [40.43202, -3.60353],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46d77ef98c776f471c9acd9595e69adf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_46d77ef98c776f471c9acd9595e69adf.addTo(map_48e9e52e53e508fbdb9ac5cb4feedce0);
#
#
#             var circle_marker_c563523e2f767c11c25d6c216ea91de0 = L.circleMarker(
#                 [40.43202, -3.60353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48e9e52e53e508fbdb9ac5cb4feedce0);
#
#
#         var popup_df6af3a4826dc5aea0a3d38bfabe75a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c63846e6269f69fc644484df60ccbf0 = $(`&lt;div id=&quot;html_4c63846e6269f69fc644484df60ccbf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_df6af3a4826dc5aea0a3d38bfabe75a0.setContent(html_4c63846e6269f69fc644484df60ccbf0);
#
#
#
#         circle_marker_c563523e2f767c11c25d6c216ea91de0.bindPopup(popup_df6af3a4826dc5aea0a3d38bfabe75a0)
#         ;
#
#
#
#
#             var circle_marker_b630ae18f4a66e7f8de069b4d2e9fb88 = L.circleMarker(
#                 [40.42756, -3.61577],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48e9e52e53e508fbdb9ac5cb4feedce0);
#
#
#         var popup_a2757733c658e3255c6a00d7a29302df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83c7d545bf6688387ce44d7f7522f4f0 = $(`&lt;div id=&quot;html_83c7d545bf6688387ce44d7f7522f4f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_a2757733c658e3255c6a00d7a29302df.setContent(html_83c7d545bf6688387ce44d7f7522f4f0);
#
#
#
#         circle_marker_b630ae18f4a66e7f8de069b4d2e9fb88.bindPopup(popup_a2757733c658e3255c6a00d7a29302df)
#         ;
#
#
#
#
#             var circle_marker_9590d51bb7ba02bb11c4efcf63fa3384 = L.circleMarker(
#                 [40.42761, -3.6158],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48e9e52e53e508fbdb9ac5cb4feedce0);
#
#
#         var popup_cc23e2a4dc59e7d3f9d93fe5a51aaeda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d3a434bf6b1069a4c7ed2450c434962 = $(`&lt;div id=&quot;html_1d3a434bf6b1069a4c7ed2450c434962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_cc23e2a4dc59e7d3f9d93fe5a51aaeda.setContent(html_1d3a434bf6b1069a4c7ed2450c434962);
#
#
#
#         circle_marker_9590d51bb7ba02bb11c4efcf63fa3384.bindPopup(popup_cc23e2a4dc59e7d3f9d93fe5a51aaeda)
#         ;
#
#
#
#
#             var circle_marker_c4f63312c46b18c3f6eeec0e39b240d0 = L.circleMarker(
#                 [40.4267, -3.61631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;:
